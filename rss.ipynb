# %%
import urllib
import pprint
import xmltodict
import feedparser

# %%
feed = feedparser.parse("http://arxiv.org/rss/astro-ph/new")

# %%
print(feed.keys())
# Out:
# dict_keys(['bozo', 'entries', 'feed', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %%
for entry in feed.entries:
    print(entry)
# Out:
# {'id': 'http://arxiv.org/abs/2312.13298', 'title': 'A Horseshoe-Shaped Ring of Diffuse Emission Detected at 1.4 GHz. (arXiv:2312.13298v1 [astro-ph.GA])', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/rss/astro-ph/new', 'value': 'A Horseshoe-Shaped Ring of Diffuse Emission Detected at 1.4 GHz. (arXiv:2312.13298v1 [astro-ph.GA])'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://arxiv.org/abs/2312.13298'}], 'link': 'http://arxiv.org/abs/2312.13298', 'summary': '<p>We identify a horseshoe-shaped ring (HSR) of diffuse emission in J1407+0453\nfrom the Faint Images of Radio Sky at Twenty-cm (FIRST) survey using the Very\nLarge Array telescope. An optical galaxy SDSSJ140709.01+045302.1 is present\nnear the limb of the HSR of J1407+0453, with a spectroscopic redshift of\n$z=0.13360$. The total extent of the source, including the diffuse emission of\nJ1407+0453, is 65 arcsec (with a physical extent of 160 kpc), whereas the\ndiame
# ...

# %%
feedlist = [entry for entry in feed.entries]

# %%
feedlist[0]
# Out:
# {'id': 'http://arxiv.org/abs/2312.13298',
#  'title': 'A Horseshoe-Shaped Ring of Diffuse Emission Detected at 1.4 GHz. (arXiv:2312.13298v1 [astro-ph.GA])',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'http://export.arxiv.org/rss/astro-ph/new',
#   'value': 'A Horseshoe-Shaped Ring of Diffuse Emission Detected at 1.4 GHz. (arXiv:2312.13298v1 [astro-ph.GA])'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'http://arxiv.org/abs/2312.13298'}],
#  'link': 'http://arxiv.org/abs/2312.13298',
# ...
